# %%
import pandas as pd

df = pd.read_excel("data/raw/planilha_analise_financeira_ml.xlsx")

# %%
print(df.isnull().sum())
# Out:
# Data                  0
# Produto               0
# Categoria             0
# Regiao                0
# Clientes              0
# Preco_Unitario        0
# Quantidade_Vendida    0
# Receita               0
# Custo                 0
# Lucro                 0
# Marketing             0
# Desconto              0
# Sazonalidade          0
# Taxa_Cambio           0
# Inflacao              0
# Concorrencia          0
# Nivel_Stock           0
# Satisfacao_Cliente    0
# Meta_Vendas           0
# Previsao_Demanda      0
# dtype: int64

# %%
print(df.describe())
# Out:
#           Clientes  Preco_Unitario  Quantidade_Vendida        Receita  \
# count  2000.000000     2000.000000          2000.00000    2000.000000
# mean    156.781000     1023.340455            50.29800   52306.289350
# std      80.569242      568.861988            28.81436   45272.720034
# min      20.000000       50.550000             1.00000     182.790000
# 25%      88.000000      524.695000            25.00000   14256.555000
# 50%     157.000000     1038.645000            51.00000   39430.485000
# 75%     226.000000     1508.975000            74.25000   79967.910000
# max     300.000000     1999.140000           100.00000  195444.340000
#
#                Custo          Lucro     Marketing     Desconto  Taxa_Cambio  \
# count    2000.000000    2000.000000   2000.000000  2000.000000  2000.000000
# mean    32830.763795   19475.525555  25894.174300    14.757535    67.302695
# std     29637.156612   19150.464324  14393.816251     8.677672     4.290815
# ...
